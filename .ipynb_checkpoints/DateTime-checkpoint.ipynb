# %%
import pandas as pd

# %%
air_quality = pd.read_csv('air_quality.csv')

# %%
air_quality.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 95685 entries, 0 to 95684
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date_time  95685 non-null  str
#  1   PM2.5      95685 non-null  float64
#  2   PM10       95685 non-null  float64
#  3   SO2        95685 non-null  float64
#  4   NO2        95685 non-null  float64
#  5   CO         95685 non-null  float64
#  6   O3         95685 non-null  float64
#  7   TEMP       95685 non-null  float64
#  8   PRES       95685 non-null  float64
#  9   DEWP       95685 non-null  float64
#  10  RAIN       95685 non-null  float64
#  11  wd         95685 non-null  str
#  12  WSPM       95685 non-null  float64
#  13  station    95685 non-null  str
# dtypes: float64(11), str(3)
# memory usage: 10.2 MB

# %%
air_quality.head()
# Out:
#              date_time  PM2.5  PM10   SO2   NO2     CO    O3  TEMP    PRES  \
# 0  2013-03-01 00:00:00    9.0   9.0   3.0  17.0  300.0  89.0  -0.5  1024.5
# 1  2013-03-01 01:00:00    4.0   4.0   3.0  16.0  300.0  88.0  -0.7  1025.1
# 2  2013-03-01 05:00:00    4.0   4.0   9.0  25.0  300.0  78.0  -2.4  1027.5
# 3  2013-03-01 06:00:00    5.0   5.0  10.0  29.0  400.0  67.0  -2.5  1028.2
# 4  2013-03-01 07:00:00    3.0   6.0  12.0  40.0  400.0  52.0  -1.4  1029.5
#
#    DEWP  RAIN   wd  WSPM station
# 0 -21.4   0.0  NNW   5.7  Dongsi
# 1 -22.1   0.0   NW   3.9  Dongsi
# 2 -21.3   0.0   NW   2.4  Dongsi
# 3 -20.4   0.0   NW   2.2  Dongsi
# 4 -20.4   0.0  NNW   3.0  Dongsi

# %%
air_quality['date_time'] = pd.to_datetime(air_quality['date_time'])

# %%
air_quality['year'] = air_quality['date_time'].dt.year
air_quality['month'] = air_quality['date_time'].dt.month
air_quality['day'] = air_quality['date_time'].dt.day
air_quality['hour'] = air_quality['date_time'].dt.hour
air_quality['quarter'] = air_quality['date_time'].dt.quarter
air_quality['day_of_week_num'] = air_quality['date_time'].dt.dayofweek
air_quality['day_of_week_name'] = air_quality['date_time' ]. dt. day_name()

air_quality[['date_time', 'year', 'month', 'day', 'hour', 'quarter', 'day_of_week_num', 'day_of_week_name']]
# Out:
#                 date_time  year  month  day  hour  quarter  day_of_week_num  \
# 0     2013-03-01 00:00:00  2013      3    1     0        1                4
# 1     2013-03-01 01:00:00  2013      3    1     1        1                4
# 2     2013-03-01 05:00:00  2013      3    1     5        1                4
# 3     2013-03-01 06:00:00  2013      3    1     6        1                4
# 4     2013-03-01 07:00:00  2013      3    1     7        1                4
# ...                   ...   ...    ...  ...   ...      ...              ...
# 95680 2017-02-28 15:00:00  2017      2   28    15        1                1
# 95681 2017-02-28 16:00:00  2017      2   28    16        1                1
# 95682 2017-02-28 21:00:00  2017      2   28    21        1                1
# 95683 2017-02-28 22:00:00  2017      2   28    22        1                1
# 95684 2017-02-28 23:00:00  2017      2   28    23        1                1
#
#       day_of_week_name
# 0               Friday
# 1               Friday
# 2               Friday
# 3               Friday
# 4               Friday
# ...                ...
# 95680          Tuesday
# 95681          Tuesday
# 95682          Tuesday
# 95683          Tuesday
# 95684          Tuesday
#
# [95685 rows x 8 columns]

# %%
air_quality[['day_of_week_num', 'day_of_week_name']].value_counts()
# Out:
# day_of_week_num  day_of_week_name
# 6                Sunday              13931
# 5                Saturday            13812
# 4                Friday              13782
# 3                Thursday            13633
# 0                Monday              13536
# 1                Tuesday             13523
# 2                Wednesday           13468
# Name: count, dtype: int64

# %%
air_quality['date_time'].max()
# Out:
# Timestamp('2017-02-28 23:00:00')

# %%
air_quality['date_time'].min()
# Out:
# Timestamp('2013-03-01 00:00:00')

# %%
date_time_range = air_quality['date_time'].max() - air_quality['date_time'].min()

# %%
pd.Timedelta(days=256)
# Out:
# Timedelta('256 days 00:00:00')

# %%
date_time_range/pd.Timedelta(days=1)
# Out:
# 1460.9583333333333

# %%
date_time_range/pd.Timedelta(days=365)
# Out:
# 4.002625570776256

# %%
pd.Timestamp('2026/01/01')
# Out:
# Timestamp('2026-01-01 00:00:00')

# %%
air_quality['time_until_2026']=pd.Timestamp('2026/01/01') - air_quality['date_time']

# %%
air_quality['time_until_2026']/pd.Timedelta(days=1)
# Out:
# 0        4689.000000
# 1        4688.958333
# 2        4688.791667
# 3        4688.750000
# 4        4688.708333
#             ...
# 95680    3228.375000
# 95681    3228.333333
# 95682    3228.125000
# 95683    3228.083333
# 95684    3228.041667
# Name: time_until_2026, Length: 95685, dtype: float64

# %%
air_quality['time_until_2026_days']=air_quality['time_until_2026']/pd.Timedelta(days=1)

# %%
air_quality['time_until_2026_weeks']=air_quality['time_until_2026']/pd.Timedelta(weeks=1)

# %%
air_quality[['date_time', 'time_until_2026', 'time_until_2026_days', 'time_until_2026_weeks']]
# Out:
#                 date_time    time_until_2026  time_until_2026_days  \
# 0     2013-03-01 00:00:00 4689 days 00:00:00           4689.000000
# 1     2013-03-01 01:00:00 4688 days 23:00:00           4688.958333
# 2     2013-03-01 05:00:00 4688 days 19:00:00           4688.791667
# 3     2013-03-01 06:00:00 4688 days 18:00:00           4688.750000
# 4     2013-03-01 07:00:00 4688 days 17:00:00           4688.708333
# ...                   ...                ...                   ...
# 95680 2017-02-28 15:00:00 3228 days 09:00:00           3228.375000
# 95681 2017-02-28 16:00:00 3228 days 08:00:00           3228.333333
# 95682 2017-02-28 21:00:00 3228 days 03:00:00           3228.125000
# 95683 2017-02-28 22:00:00 3228 days 02:00:00           3228.083333
# 95684 2017-02-28 23:00:00 3228 days 01:00:00           3228.041667
#
#        time_until_2026_weeks
# 0                 669.857143
# 1                 669.851190
# 2                 669.827381
# 3                 669.821429
# 4                 669.815476
# ...                      ...
# 95680             461.196429
# 95681             461.190476
# 95682             461.160714
# 95683             461.154762
# 95684             461.148810
#
# [95685 rows x 4 columns]

# %%
air_quality['prior_2026_ind']=air_quality['date_time']<pd.Timestamp('2016/01/01')

# %%
air_quality[['date_time', 'prior_2026_ind']]
# Out:
#                 date_time  prior_2026_ind
# 0     2013-03-01 00:00:00            True
# 1     2013-03-01 01:00:00            True
# 2     2013-03-01 05:00:00            True
# 3     2013-03-01 06:00:00            True
# 4     2013-03-01 07:00:00            True
# ...                   ...             ...
# 95680 2017-02-28 15:00:00           False
# 95681 2017-02-28 16:00:00           False
# 95682 2017-02-28 21:00:00           False
# 95683 2017-02-28 22:00:00           False
# 95684 2017-02-28 23:00:00           False
#
# [95685 rows x 2 columns]

# %%
print(air_quality.head())
air_quality = air_quality.set_index(air_quality['date_time'])
# Out:
#             date_time  PM2.5  PM10   SO2   NO2     CO    O3  TEMP    PRES  \
# 0 2013-03-01 00:00:00    9.0   9.0   3.0  17.0  300.0  89.0  -0.5  1024.5
# 1 2013-03-01 01:00:00    4.0   4.0   3.0  16.0  300.0  88.0  -0.7  1025.1
# 2 2013-03-01 05:00:00    4.0   4.0   9.0  25.0  300.0  78.0  -2.4  1027.5
# 3 2013-03-01 06:00:00    5.0   5.0  10.0  29.0  400.0  67.0  -2.5  1028.2
# 4 2013-03-01 07:00:00    3.0   6.0  12.0  40.0  400.0  52.0  -1.4  1029.5
#
#    DEWP  ...  month day  hour quarter  day_of_week_num  day_of_week_name  \
# 0 -21.4  ...      3   1     0       1                4            Friday
# 1 -22.1  ...      3   1     1       1                4            Friday
# 2 -21.3  ...      3   1     5       1                4            Friday
# 3 -20.4  ...      3   1     6       1                4            Friday
# 4 -20.4  ...      3   1     7       1                4            Friday
#
#      time_until_2026  time_until_2026_days  time_until_2026_weeks  \
# 0 4689 days 00:00:00           4689.000000             669.857143
# 1 4688 days 23:00:00           4688.958333             669.851190
# 2 4688 days 19:00:00           4688.791667             669.827381
# 3 4688 days 18:00:00           4688.750000             669.821429
# 4 4688 days 17:00:00           4688.708333             669.815476
#
#    prior_2026_ind
# 0            True
# 1            True
# 2            True
# 3            True
# 4            True
#
# [5 rows x 25 columns]

# %%
air_quality.set_index('date_time', inplace=True)

if 'date_time' in air_quality.columns:
    air_quality.drop(columns='date_time', inplace=True)

# %%
air_quality.head()
# Out:
#                      PM2.5  PM10   SO2   NO2     CO    O3  TEMP    PRES  DEWP  \
# date_time
# 2013-03-01 00:00:00    9.0   9.0   3.0  17.0  300.0  89.0  -0.5  1024.5 -21.4
# 2013-03-01 01:00:00    4.0   4.0   3.0  16.0  300.0  88.0  -0.7  1025.1 -22.1
# 2013-03-01 05:00:00    4.0   4.0   9.0  25.0  300.0  78.0  -2.4  1027.5 -21.3
# 2013-03-01 06:00:00    5.0   5.0  10.0  29.0  400.0  67.0  -2.5  1028.2 -20.4
# 2013-03-01 07:00:00    3.0   6.0  12.0  40.0  400.0  52.0  -1.4  1029.5 -20.4
#
#                      RAIN  ... month  day hour  quarter  day_of_week_num  \
# date_time                  ...
# 2013-03-01 00:00:00   0.0  ...     3    1    0        1                4
# 2013-03-01 01:00:00   0.0  ...     3    1    1        1                4
# 2013-03-01 05:00:00   0.0  ...     3    1    5        1                4
# 2013-03-01 06:00:00   0.0  ...     3    1    6        1                4
# 2013-03-01 07:00:00   0.0  ...     3    1    7        1                4
#
#                      day_of_week_name    time_until_2026  \
# date_time
# 2013-03-01 00:00:00            Friday 4689 days 00:00:00
# 2013-03-01 01:00:00            Friday 4688 days 23:00:00
# 2013-03-01 05:00:00            Friday 4688 days 19:00:00
# 2013-03-01 06:00:00            Friday 4688 days 18:00:00
# 2013-03-01 07:00:00            Friday 4688 days 17:00:00
#
#                      time_until_2026_days  time_until_2026_weeks  \
# date_time
# 2013-03-01 00:00:00           4689.000000             669.857143
# 2013-03-01 01:00:00           4688.958333             669.851190
# 2013-03-01 05:00:00           4688.791667             669.827381
# 2013-03-01 06:00:00           4688.750000             669.821429
# 2013-03-01 07:00:00           4688.708333             669.815476
#
#                     prior_2026_ind
# date_time
# 2013-03-01 00:00:00           True
# 2013-03-01 01:00:00           True
# 2013-03-01 05:00:00           True
# 2013-03-01 06:00:00           True
# 2013-03-01 07:00:00           True
#
# [5 rows x 24 columns]

# %%
air_quality = air_quality.sort_index()
air_quality.loc['2013-01':'2013-02']
# Out:
# Empty DataFrame
# Columns: [PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM, station, year, month, day, hour, quarter, day_of_week_num, day_of_week_name, time_until_2026, time_until_2026_days, time_until_2026_weeks, prior_2026_ind]
# Index: []
#
# [0 rows x 24 columns]

# %%
air_quality.loc['2013':, 'TEMP'].plot()
# Out:
# <Axes: xlabel='date_time'>

# %%
air_quality.asfreq(freq='1W-FRI', method='ffill')
# Out:
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 air_quality.nunique().asfreq(freq='1W-FRI', method='ffill')
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:8901, in NDFrame.asfreq(self, freq, method, how, normalize, fill_value)
#    8897         2000-01-01 00:03:00    3.0
#    8898         """
#    8899         from pandas.core.resample import asfreq
#    8900
# -> 8901         return asfreq(
#    8902             self,
#    8903             freq,
#    8904             method=method,
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\resample.py:3115, in asfreq(obj, freq, method, how, normalize, fill_value)
#    3112 if isinstance(obj.index, DatetimeIndex):
#    3113     # TODO: should we disallow non-DatetimeIndex?
#    3114     unit = obj.index.unit
# -> 3115 dti = date_range(obj.index.min(), obj.index.max(), freq=freq, unit=unit)
#    3116 dti.name = obj.index.name
#    3117 new_obj = obj.reindex(dti, method=method, fill_value=fill_value)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\datetimes.py:1491, in date_range(start, end, periods, freq, tz, normalize, name, inclusive, unit, **kwargs)
#    1488             elif getattr(freq, "milliseconds", 0) != 0 and unit not in ["ns", "us"]:
#    1489                 unit = "ms"
# -> 1491 dtarr = DatetimeArray._generate_range(
#    1492     start=start,
#    1493     end=end,
#    1494     periods=periods,
#    1495     freq=freq,
#    1496     tz=tz,
#    1497     normalize=normalize,
#    1498     inclusive=inclusive,
#    1499     unit=unit,
#    1500     **kwargs,
#    1501 )
#    1502 return DatetimeIndex._simple_new(dtarr, name=name)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arrays\datetimes.py:440, in DatetimeArray._generate_range(cls, start, end, periods, freq, tz, normalize, ambiguous, nonexistent, inclusive, unit)
#     437 freq = to_offset(freq)
#     439 if start is not None:
# --> 440     start = Timestamp(start)
#     442 if end is not None:
#     443     end = Timestamp(end)
#
# File pandas/_libs/tslibs/timestamps.pyx:2738, in pandas._libs.tslibs.timestamps.Timestamp.__new__()
# -> 2738 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/tslibs/conversion.pyx:367, in pandas._libs.tslibs.conversion.convert_to_tsobject()
# --> 367 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/tslibs/conversion.pyx:658, in pandas._libs.tslibs.conversion.convert_str_to_tsobject()
# --> 658 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/tslibs/parsing.pyx:321, in pandas._libs.tslibs.parsing.parse_datetime_string()
# --> 321 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/tslibs/parsing.pyx:652, in pandas._libs.tslibs.parsing.dateutil_parse()
# --> 652 'Could not get source, probably due dynamically evaluated source code.'
#
# DateParseError: Unknown datetime string format, unable to parse: CO
