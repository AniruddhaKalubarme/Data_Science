# %%
import pandas as pd
data = pd.read_csv('marvel_characters_dataset.csv')
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#          Character         Real Name Affiliation  \
# 0         iron man        Tony Stark    Avengers
# 1  captain america      Steve Rogers    Avengers
# 2             thor      Thor Odinson    Avengers
# 3      black widow  Natasha Romanoff    Avengers
# 4             hulk      Bruce Banner    Avengers
#
#                                   Powers  Role Power Level
# 0  Powered Armor, Genius-level intellect  Hero         Low
# 1       Super Soldier, Enhanced strength  Hero         Low
# 2   God of Thunder, Weather manipulation  Hero         Low
# 3         Superhuman strength, Espionage  Hero         Low
# 4   Superhuman strength, Gamma Radiation  Hero         Low

# %%
df['Role'] = df['Role'] + 'str'

# %%
df.loc[2, 'Role'] = 'Aniruddha'

# %%
df.head()
# Out:
#          Character         Real Name Affiliation  \
# 0         iron man        Tony Stark    Avengers
# 1  captain america      Steve Rogers    Avengers
# 2             thor      Thor Odinson    Avengers
# 3      black widow  Natasha Romanoff    Avengers
# 4             hulk      Bruce Banner    Avengers
#
#                                   Powers       Role Power Level
# 0  Powered Armor, Genius-level intellect    Herostr         Low
# 1       Super Soldier, Enhanced strength    Herostr         Low
# 2   God of Thunder, Weather manipulation  Aniruddha         Low
# 3         Superhuman strength, Espionage    Herostr         Low
# 4   Superhuman strength, Gamma Radiation    Herostr         Low

# %%
df.iloc[3,2:4] = 'doreamon'

# %%
df.head()
# Out:
#          Character         Real Name Affiliation  \
# 0         iron man        Tony Stark    Avengers
# 1  captain america      Steve Rogers    Avengers
# 2             thor      Thor Odinson    Avengers
# 3      black widow  Natasha Romanoff    doreamon
# 4             hulk      Bruce Banner    Avengers
#
#                                   Powers       Role Power Level
# 0  Powered Armor, Genius-level intellect    Herostr         Low
# 1       Super Soldier, Enhanced strength    Herostr         Low
# 2   God of Thunder, Weather manipulation  Aniruddha         Low
# 3                               doreamon    Herostr         Low
# 4   Superhuman strength, Gamma Radiation    Herostr         Low

# %%
df['Age'] = range(df.shape[0])

# %%
df.head()
# Out:
#          Character         Real Name Affiliation  \
# 0         iron man        Tony Stark    Avengers
# 1  captain america      Steve Rogers    Avengers
# 2             thor      Thor Odinson    Avengers
# 3      black widow  Natasha Romanoff    doreamon
# 4             hulk      Bruce Banner    Avengers
#
#                                   Powers       Role Power Level  Age
# 0  Powered Armor, Genius-level intellect    Herostr         Low   20
# 1       Super Soldier, Enhanced strength    Herostr         Low   21
# 2   God of Thunder, Weather manipulation  Aniruddha         Low   22
# 3                               doreamon    Herostr         Low   23
# 4   Superhuman strength, Gamma Radiation    Herostr         Low   24

# %%
df['Age'] = df['Age']+15

# %%
df.head()
# Out:
#          Character         Real Name Affiliation  \
# 0         iron man        Tony Stark    Avengers
# 1  captain america      Steve Rogers    Avengers
# 2             thor      Thor Odinson    Avengers
# 3      black widow  Natasha Romanoff    doreamon
# 4             hulk      Bruce Banner    Avengers
#
#                                   Powers       Role Power Level  Age
# 0  Powered Armor, Genius-level intellect    Herostr         Low   35
# 1       Super Soldier, Enhanced strength    Herostr         Low   36
# 2   God of Thunder, Weather manipulation  Aniruddha         Low   37
# 3                               doreamon    Herostr         Low   38
# 4   Superhuman strength, Gamma Radiation    Herostr         Low   39

# %%
df['Character'] = df['Character'].apply(str.upper)

# %%
df.head()
# Out:
#          Character         Real Name Affiliation  \
# 0         IRON MAN        Tony Stark    Avengers
# 1  CAPTAIN AMERICA      Steve Rogers    Avengers
# 2             THOR      Thor Odinson    Avengers
# 3      BLACK WIDOW  Natasha Romanoff    doreamon
# 4             HULK      Bruce Banner    Avengers
#
#                                   Powers       Role Power Level  Age
# 0  Powered Armor, Genius-level intellect    Herostr         Low   35
# 1       Super Soldier, Enhanced strength    Herostr         Low   36
# 2   God of Thunder, Weather manipulation  Aniruddha         Low   37
# 3                               doreamon    Herostr         Low   38
# 4   Superhuman strength, Gamma Radiation    Herostr         Low   39

# %%
df['Character'] = df['Character'].map({'IRON MAN':"Nobita", 'THOR':'Giyan'})

# %%
df.head()
# Out:
#   Character         Real Name Affiliation  \
# 0    Nobita        Tony Stark    Avengers
# 1       NaN      Steve Rogers    Avengers
# 2     Giyan      Thor Odinson    Avengers
# 3       NaN  Natasha Romanoff    doreamon
# 4       NaN      Bruce Banner    Avengers
#
#                                   Powers       Role Power Level  Age
# 0  Powered Armor, Genius-level intellect    Herostr         Low   35
# 1       Super Soldier, Enhanced strength    Herostr         Low   36
# 2   God of Thunder, Weather manipulation  Aniruddha         Low   37
# 3                               doreamon    Herostr         Low   38
# 4   Superhuman strength, Gamma Radiation    Herostr         Low   39

# %%
df['Age'] = df['Age'].mask(df['Age']>36, 0)

# %%
df.head()
# Out:
#   Character         Real Name Affiliation  \
# 0    Nobita        Tony Stark    Avengers
# 1       NaN      Steve Rogers    Avengers
# 2     Giyan      Thor Odinson    Avengers
# 3       NaN  Natasha Romanoff    doreamon
# 4       NaN      Bruce Banner    Avengers
#
#                                   Powers       Role Power Level  Age
# 0  Powered Armor, Genius-level intellect    Herostr         Low   35
# 1       Super Soldier, Enhanced strength    Herostr         Low   36
# 2   God of Thunder, Weather manipulation  Aniruddha         Low    0
# 3                               doreamon    Herostr         Low    0
# 4   Superhuman strength, Gamma Radiation    Herostr         Low    0

# %%
df_ref = df
df_copy = df.copy()

# %%
print('sorting the data')
# Out:
# sorting the data

# %%
df.sort_values(by='Real Name').head()
# Out:
#    Character           Real Name     Affiliation  \
# 37       NaN           Ben Grimm  Fantastic Four
# 31       NaN  Blackagar Boltagon        Avengers
# 4        NaN        Bruce Banner        Avengers
# 30       NaN          Brunnhilde       Defenders
# 14       NaN          Carl Lucas       Defenders
#
#                                        Powers     Role Power Level  Age
# 37       Invisibility, Force field generation  Herostr         Low    0
# 31                Illusion creation, Hypnosis  Herostr         Low    0
# 4        Superhuman strength, Gamma Radiation  Herostr         Low    0
# 30  Superhuman intelligence, Tentacle control  Herostr         Low    0
# 14      Superhuman strength, Bulletproof skin  Herostr         Low    0

# %%
df.sort_values(by='Real Name', ascending=False).head()
# Out:
#    Character        Real Name Affiliation  \
# 11       NaN   Wanda Maximoff    Avengers
# 7        NaN      Wade Wilson     X-Force
# 20       NaN  Victor Von Doom     Villain
# 12       NaN  Victor Von Doom    Avengers
# 8        NaN         T’Challa    Avengers
#
#                                           Powers         Role Power Level  Age
# 11                  Telekinesis, Reality warping      Herostr         Low    0
# 7   Regeneration, Skilled hand-to-hand combatant  Antiherostr         Low    0
# 20             Superhuman strength, Regeneration   Villainstr         Low    0
# 12                       Genius intellect, Magic      Herostr         Low    0
# 8            Superhuman strength, Vibranium suit      Herostr         Low    0

# %%
df[['Real Name', 'Affiliation']].sort_values(by=['Real Name', 'Affiliation']).head()
# Out:
#              Real Name     Affiliation
# 37           Ben Grimm  Fantastic Four
# 31  Blackagar Boltagon        Avengers
# 4         Bruce Banner        Avengers
# 30          Brunnhilde       Defenders
# 14          Carl Lucas       Defenders

# %%
df[['Real Name', 'Affiliation']].sort_values(by=['Real Name', 'Affiliation'], ascending=[True, False]).head()
# Out:
#              Real Name     Affiliation
# 37           Ben Grimm  Fantastic Four
# 31  Blackagar Boltagon        Avengers
# 4         Bruce Banner        Avengers
# 30          Brunnhilde       Defenders
# 14          Carl Lucas       Defenders

# %%
df.nlargest(n=10, columns='Age')
# Out:
#   Character         Real Name Affiliation  \
# 1       NaN      Steve Rogers    Avengers
# 0    Nobita        Tony Stark    Avengers
# 2     Giyan      Thor Odinson    Avengers
# 3       NaN  Natasha Romanoff    doreamon
# 4       NaN      Bruce Banner    Avengers
# 5       NaN      Peter Parker    Avengers
# 6       NaN     James Howlett       X-Men
# 7       NaN       Wade Wilson     X-Force
# 8       NaN          T’Challa    Avengers
# 9       NaN   Stephen Strange    Avengers
#
#                                          Powers         Role Power Level  Age
# 1              Super Soldier, Enhanced strength      Herostr         Low   36
# 0         Powered Armor, Genius-level intellect      Herostr         Low   35
# 2          God of Thunder, Weather manipulation    Aniruddha         Low    0
# 3                                      doreamon      Herostr         Low    0
# 4          Superhuman strength, Gamma Radiation      Herostr         Low    0
# ...

# %%
df[df['Age']>30].nlargest(n=10, columns='Age')
# Out:
#   Character     Real Name Affiliation                                 Powers  \
# 1       NaN  Steve Rogers    Avengers       Super Soldier, Enhanced strength
# 0    Nobita    Tony Stark    Avengers  Powered Armor, Genius-level intellect
#
#       Role Power Level  Age
# 1  Herostr         Low   36
# 0  Herostr         Low   35

# %%
df.nsmallest(n=10, columns='Age')
# Out:
#    Character         Real Name Affiliation  \
# 2      Giyan      Thor Odinson    Avengers
# 3        NaN  Natasha Romanoff    doreamon
# 4        NaN      Bruce Banner    Avengers
# 5        NaN      Peter Parker    Avengers
# 6        NaN     James Howlett       X-Men
# 7        NaN       Wade Wilson     X-Force
# 8        NaN          T’Challa    Avengers
# 9        NaN   Stephen Strange    Avengers
# 10       NaN        Scott Lang    Avengers
# 11       NaN    Wanda Maximoff    Avengers
#
#                                           Powers         Role Power Level  Age
# 2           God of Thunder, Weather manipulation    Aniruddha         Low    0
# 3                                       doreamon      Herostr         Low    0
# 4           Superhuman strength, Gamma Radiation      Herostr         Low    0
# 5                    Spider sense, Wall crawling      Herostr         Low    0
# 6                 Regeneration, Adamantium claws      Herostr         Low    0
# ...

# %%
df.nsmallest(n=10, columns='Real Name')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df.nsmallest(n=10, columns='Real Name')
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:7778, in DataFrame.nsmallest(self, n, columns, keep)
#    7668 def nsmallest(
#    7669     self, n: int, columns: IndexLabel, keep: NsmallestNlargestKeep = "first"
#    7670 ) -> DataFrame:
#    7671     """
#    7672     Return the first `n` rows ordered by `columns` in ascending order.
#    7673
#    (...)   7776     Nauru         337000  182      NR
#    7777     """
# -> 7778     return selectn.SelectNFrame(self, n=n, keep=keep, columns=columns).nsmallest()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\methods\selectn.py:61, in SelectN.nsmallest(self)
#      59 @final
#      60 def nsmallest(self):
# ...
