# %%
import numpy as np
import matplotlib.pyplot as plt
# Uniform distribution
uni = np.random.uniform(low=0, high=10, size=1000)

# Normal distribution
norm = np.random.normal(loc=50, scale=5, size=1000)

# %%
plt.hist(x=uni)
# Out:
# (array([100.,  98., 108.,  90., 105., 101.,  90., 106.,  93., 109.]),
#  array([0.01079374, 1.00800361, 2.00521348, 3.00242335, 3.99963322,
#         4.99684309, 5.99405296, 6.99126282, 7.98847269, 8.98568256,
#         9.98289243]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(x=norm)
# Out:
# (array([  3.,   6.,  45., 119., 251., 246., 185., 104.,  37.,   4.]),
#  array([32.27811048, 35.59467163, 38.91123277, 42.22779392, 45.54435506,
#         48.8609162 , 52.17747735, 55.49403849, 58.81059964, 62.12716078,
#         65.44372192]),
#  <BarContainer object of 10 artists>)
